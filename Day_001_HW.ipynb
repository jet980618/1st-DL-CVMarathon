# %%
# 作業1
import numpy as np
import matplotlib.pyplot as plt

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = np.mean((y - yp)**2) 
    return mse
    
    
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 197.442
# The Mean absolute error is 10.953

# %%
# 作業2

# 1. 你選的這組資料為何重要
# ANS: 目前武漢疫情嚴重，透過數據收集分析疫情發展

# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# ANS: 由 Johns Hopkins University 提供
    
# 3. 蒐集而來的資料型態為何
# ANS: 為每個國家/地區，每日確診、疑似、康復及死亡人數
    
# 4. 這組資料想解決的問題如何評估
# ANS: 由數據的發展，關聯時間軸與確診、疑似、康復及死亡人數，最後預測出該地區疫情結束的機率
# Out:
#   File "<ipython-input-5-10d5795490a2>", line 4
#     ANS:
#         ^
# SyntaxError: invalid syntax

# %%
# 作業3
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
ANS: 如何提升載客率
    
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
ANS: 收集每日載客的區域、星期幾、時間、天氣、是否假日
地點可顯示出哪些地區是熱點，搭乘率高
日期、時間亦可顯示出搭乘的熱門時段
天氣可反應出搭乘意願(雨天搭乘機率高)
皆由每日司機紀錄每個小時的載客狀況

3. 蒐集而來的資料型態為何
數據資料

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
input:區域、星期幾、時間、天氣、是否假日
output: 載客機率

透過比對載客率來判斷準確度誤差
# Out:
#   File "<ipython-input-2-da40ee30bdfc>", line 2
#     1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#             ^
# SyntaxError: invalid syntax
